# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Get Datset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RdwzlIKifZ9ybbiSIIbH")
project = rf.workspace("kyles-workspace").project("basketball-players-detection-flths")
version = project.version(2)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\keias\\Documents\\Basketball-Tracker\\training\\basketball-players-detection-2'

# %%
# import shutil

# shutil.move('basketball-players-detection-2/train',
#             'basketball-players-detection-2/basketball-players-detection-2/train')

# shutil.move('basketball-players-detection-2/test',
#             'basketball-players-detection-2/basketball-players-detection-2/test')

# shutil.move('basketball-players-detection-2/valid',
#             'basketball-players-detection-2/basketball-players-detection-2/valid')

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ^C
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.3.3 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.100 🚀 Python-3.11.5 torch-2.4.1+cpu CPU (12th Gen Intel Core(TM) i9-12900K)
# ...
